# %% [markdown]
# # Yelp Data Challenge - Restaurant Recommender
#
# BitTiger DS501
#
# Nov 2017

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline
plt.style.use("ggplot")

# %%
df = pd.read_csv('data/last_2_years_restaurant_reviews.csv')
# Out:
# /Users/iris/anaconda2/envs/py36/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (0,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#   Unnamed: 0             business_id name  categories  avg_stars  cool  \
# 0          0  0W4lkclzZThpx3V65bVgig  NaN         NaN        NaN   0.0
# 1          1  AEx2SYEUJmTxVVB18LlCwA  NaN         NaN        NaN   0.0
# 2          2  VR6GpWIda3SfvPC-lg9H3w  NaN         NaN        NaN   0.0
# 3          3  CKC0-MOWMqoeWf6s-szl8g  NaN         NaN        NaN   0.0
# 4          4  ACFtxLv8pGrrxMm6EgjreA  NaN         NaN        NaN   0.0
#
#          date  funny               review_id  stars  \
# 0  2016-05-28    0.0  v0i_UHJMo_hPBq9bxWvW4w    5.0
# 1  2016-05-28    0.0  vkVSCC7xljjrAI4UGfnKEQ    5.0
# 2  2016-05-28    0.0  n6QzIUObkYshz4dz2QRJTw    5.0
# 3  2016-05-28    0.0  MV3CcKScW05u5LVfF6ok0g    5.0
# 4  2016-05-28    0.0  IXvOzsEMYtiJI0CARmj77Q    4.0
#
#                                                 text  useful  \
# 0  Love the staff, love the meat, love the place....     0.0
# 1  Super simple place but amazing nonetheless. It...     0.0
# 2  Small unassuming place that changes their menu...     0.0
# 3  Lester's is located in a beautiful neighborhoo...     0.0
# 4  Love coming here. Yes the place always needs t...     0.0
#
#                   user_id
# 0  bv2nCi5Qv5vroFiqKGopiw
# 1  bv2nCi5Qv5vroFiqKGopiw
# 2  bv2nCi5Qv5vroFiqKGopiw
# 3  bv2nCi5Qv5vroFiqKGopiw
# 4  bv2nCi5Qv5vroFiqKGopiw

# %% [markdown]
# ## 1. Clean data and get rating data

# %% [markdown]
# #### Select relevant columns in the original dataframe

# %%
# Get business_id, user_id, stars for recommender
df = df[['business_id','user_id','stars']]
df
# Out:
#                     business_id                 user_id  stars
# 0        0W4lkclzZThpx3V65bVgig  bv2nCi5Qv5vroFiqKGopiw    5.0
# 1        AEx2SYEUJmTxVVB18LlCwA  bv2nCi5Qv5vroFiqKGopiw    5.0
# 2        VR6GpWIda3SfvPC-lg9H3w  bv2nCi5Qv5vroFiqKGopiw    5.0
# 3        CKC0-MOWMqoeWf6s-szl8g  bv2nCi5Qv5vroFiqKGopiw    5.0
# 4        ACFtxLv8pGrrxMm6EgjreA  bv2nCi5Qv5vroFiqKGopiw    4.0
# 5        s2I_Ni76bjJNK9yG60iD-Q  bv2nCi5Qv5vroFiqKGopiw    4.0
# 6        gkCorLgPyQLsptTHalL61g  u0LXt3Uea_GidxRW1xcsfg    4.0
# 7        fDF_o2JPU8BR1Gya--jRIA  u0LXt3Uea_GidxRW1xcsfg    5.0
# 8        AIUFSIIdCEi3XoRJaxtDLQ  u0LXt3Uea_GidxRW1xcsfg    4.0
#
4Iwu57GSychxpqa4w4HAMQ    5.0
# 3048272  jfmyj519pg2flxGEQ2xdPg  4Iwu57GSychxpqa4w4HAMQ    4.0
# 3048273  _vHI2zsJp7b02MFJUWJgbw  4Iwu57GSychxpqa4w4HAMQ    5.0
# 3048274  r3Tl_uO_O5jLQ_IhP0_caw  8LkXi8S8VdnEoOB97RNOJw    5.0
# 3048275  JDjOobEd_Tm6Z06YRmWkbg  kjXJhMQUy8OBSnbrMJeLVQ    1.0
# 3048276  a2ZBDIXmwBm7IWnXR6LK-g  kjXJhMQUy8OBSnbrMJeLVQ    5.0
# 3048277  sR9hPrIaG-J-GLcl4yaiLw  kjXJhMQUy8OBSnbrMJeLVQ    5.0
# 3048278  zkw-peCF6FDKuopAp8LBzw  kjXJhMQUy8OBSnbrMJeLVQ    5.0
# 3048279  mdpA_D1lwFFpgdXr1PtfpA  kjXJhMQUy8OBSnbrMJeLVQ    5.0
# 3048280  ysv6yhVYOoH9Pf7PlMyD0g  n9a7RhvdydX4oesmtjTGKg    1.0
# 3048281  xTVH9u9vuub_v_YHFveDoQ  VNixwdIgSE3GkPm2bSq8Aw    4.0
# 3048282  LkMtMHVetws5_7QfRjPtlg  jcXu20szpGPe9hDq9AR-ZA    4.0
# 3048283  lLMJsTchKYF1O0fpNWpCRA  4wA_CZT08V3d8cGaAWuXog    5.0
# 3048284  5ftAE8C6KiEPGJbmScln_g  vPCYOCTMTixFXn1_60UjJQ    1.0
# 3048285  HeKfDaa_Fa0fn3-xy9tqDw  CPIGdVV2ByLA_nqP1F4S-Q    5.0
# 3048286  096qNc7waeRlReivCm2lXw  mPjPyipaD0C_myqWqDipZg    3.0
# 3048287  gnkyosoOepBUqog7iDdggQ  mPjPyipaD0C_myqWqDipZg    4.0
# 3048288  OsB_ZtFAaLDCPzvlAjHQ-w  mPjPyipaD0C_myqWqDipZg    3.0
# 3048289  AtUtG-oQp1rkk6ZdYcfSzw  mPjPyipaD0C_myqWqDipZg    2.0
# 3048290  n0NH0FW8NU3zfeJY3QluMQ  mPjPyipaD0C_myqWqDipZg    3.0
# 3048291  pOEL97ld-FJMKO8Ki8JmYg  mPjPyipaD0C_myqWqDipZg    3.0
#
# [3048292 rows x 3 columns]

# %% [markdown]
# #### There are many users that haven't given many reviews, exclude these users from the item-item similarity recommender
#
# **Q**: How do we recommend to these users anyways?

# %%
# To be implemented

pass

# %% [markdown]
# #### Create utility matrix from records

# %%
# To be implemented

pass

# %% [markdown]
# ## 2. Item-Item similarity recommender

# %% [markdown]
# ### Let's reuse the ItemItemRecommender class derived from previous exercise
#
# Hint: we need to make modification to accommodate the dense numpy array

# %%
# To be implemented

pass

# %% [markdown]
# ## 3. Matrix Factorization recommender
#
# ##### Compare two of the methods demoed in Practice Class: sklearn NMF, sklearn TruncatedSVD, or GraphLab
# ##### *Extra points for using GraphLab

# %% [markdown]
# ## 4. Other recommenders (optional)
#
# What are other ways you can build a better recommender?
#
# * Other features (have you noticed there are other features in the Yelp dataset, e.g. tips, etc.?)
# * Popularity-based
# * Content-based
# * Hybrid
